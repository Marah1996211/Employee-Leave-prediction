# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
labels_text = ['Payment Tier',
'Gender',
'Education',
'Age',
'Joining Year',
'Experience in Current Field',
              'Other']

percentages = [18, 15.4, 14.1, 13.9, 11.8, 8.8, 18]

segment_colors = ["red", "orange", "lightcoral", "lightskyblue", "yellow","green", "purple"]

# %%
plt.pie(percentages,labels=labels_text, colors = segment_colors, autopct="%1.1f%%", shadow=True, startangle = 140 )
plt.show()

# %%
import pandas as pd 
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler
import numpy as np

# %%
# pulling the csv into a dataframe
employee_df = pd.read_csv('./resources/Employee.csv')
# displaying the data drame
employee_df.head()
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# 2                          2           0
# 3                          5           1
# 4                          2           1

# %%
# converting the columns with words into boolen
employee_city = pd.get_dummies(employee_df[['Education','City', 'Age', 'EverBenched']])
#displaying the dataframe
employee_city
# Out:
#       Age  Education_Bachelors  Education_Masters  Education_PHD  \
# 0      34                 True              False          False
# 1      28                 True              False          False
# 2      38                 True              False          False
# 3      27                False               True          False
# 4      24                False               True          False
# ...   ...                  ...                ...            ...
# 4648   26                 True              False          False
# 4649   37                False               True          False
# 4650   27                False               True          False
# 4651   30                 True              False          False
# 4652   33                 True              False          False
#
#       City_Bangalore  City_New Delhi  City_Pune  EverBenched_No  \
# 0               True           False      False            True
# ...

# %%
# joining the Two dataframes 
Joined_df = pd.merge(employee_df,employee_city,)
Joined_df.head()
# Out:
#    Education  JoiningYear       City  PaymentTier  Age Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34   Male          No
# 1  Bachelors         2017  Bangalore            3   34   Male          No
# 2  Bachelors         2017  Bangalore            3   34   Male          No
# 3  Bachelors         2017  Bangalore            3   34   Male          No
# 4  Bachelors         2017  Bangalore            3   34   Male          No
#
#    ExperienceInCurrentDomain  LeaveOrNot  Education_Bachelors  \
# 0                          0           0                 True
# 1                          0           0                 True
# 2                          0           0                 True
# 3                          0           0                 True
# 4                          0           0                 True
#
#    Education_Masters  Education_PHD  City_Bangalore  City_New Delhi  \
# 0              False          False            True           False
# ...

# %%
# Seperate the features, X,  from the target variable, y


y = np.array(Joined_df[['LeaveOrNot']])
X = np.array(Joined_df.drop(columns=['Education','City', 'Age', 'EverBenched','Gender','LeaveOrNot']))

# %%
# testing the data

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# scaling the data
scaler = StandardScaler()
X_scaler = scaler.fit(X_train)
X_train = X_scaler.fit_transform(X_train)
X_test = X_scaler.transform(X_test)

# %%
# the creating model code was pulled from the following URL https://builtin.com/artificial-intelligence/gaussian-naive-bayes

# %%
#creating  the model 
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# C:\Users\Raysh\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GaussianNB()

# %%
model.score(X_test, y_test)
# Out:
# 0.6221633254248948

# %%
model.score(X_test, y_test)
# Out:
# 0.6221633254248948

# %%
Y_var_pred= model.predict(X_test)

# %%
print(classification_report(y_test, Y_var_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.85      0.75    295902
#            1       0.41      0.19      0.26    157622
#
#     accuracy                           0.62    453524
#    macro avg       0.54      0.52      0.50    453524
# weighted avg       0.57      0.62      0.58    453524
